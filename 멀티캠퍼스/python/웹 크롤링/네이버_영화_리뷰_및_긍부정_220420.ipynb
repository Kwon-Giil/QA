# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk
# !pip3 install konlpy

# %%
from konlpy.tag import Okt
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
train_data=pd.read_table('ratings_train.txt')
test_data=pd.read_table('ratings_test.txt')

# %%
# train/test 데이터 갯수 확인
print(f'훈련용 리뷰 데이터:{train_data.shape}')
print(f'테스트용 리뷰 데이터:{test_data.shape}')
# Out:
# 훈련용 리뷰 데이터:(150000, 3)
# 테스트용 리뷰 데이터:(50000, 3)

# %%
# 중복 데이터 확인
print(len(train_data['document'].unique()))
print(len(test_data['document'].unique()))
# Out:
# 146183
# 49158

# %%
# 중복 데이터 제거
train_data.drop_duplicates(subset=['document'], inplace=True)

# %%
# 학습 데이터 개수 확인
print(len(train_data))
# Out:
# 146183

# %%
# 학습 데이터의 레이블 구성 비율 확인
print(train_data['label'].value_counts())
train_data['label'].value_counts().plot(kind='bar')
# Out:
# 0    73342
# 1    72841
# Name: label, dtype: int64

# %%
print(train_data.groupby('label').size().reset_index(name='count'))
# Out:
#    label  count
# 0      0  73342
# 1      1  72841

# %%
# 결측지 존재 여부 확인
train_data.isnull().values.any()
# Out:
# True

# %%
# 필드별 결측지 갯수 확인
train_data.isnull().sum()
# Out:
# id          0
# document    1
# label       0
# dtype: int64

# %%
# nan 데이터 확인
train_data.loc[train_data.document.isna()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
# NaN 값 제거
train_data=train_data.dropna(how="any")  # 결측지가 존재하는 행 삭제
train_data.isnull().values.any()
# Out:
# False

# %%
print(f'훈련용 리뷰 데이터:{train_data.shape}')
# Out:
# 훈련용 리뷰 데이터:(146182, 3)

# %%
train_data['document']
# Out:
# 0                                       아 더빙.. 진짜 짜증나네요 목소리
# 1                         흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                             교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
#                                 ...
# 149995                                  인간이 문제지.. 소는 뭔죄인가..
# 149996                                        평점이 너무 낮아서...
# 149997                      이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?
# 149998                          청춘 영화의 최고봉.방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 146182, dtype: object

# %%
train_data['document']=train_data['document'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]',"")
train_data['document']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# 0                                         아 더빙 진짜 짜증나네요 목소리
# 1                                흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                         너무재밓었다그래서보는것을추천한다
# 3                                 교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4         사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
#                                 ...
# 149995                                      인간이 문제지 소는 뭔죄인가
# 149996                                           평점이 너무 낮아서
# 149997                        이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다
# 149998                           청춘 영화의 최고봉방황과 우울했던 날들의 자화상
# 149999                             한국 영화 최초로 수간하는 내용이 담긴 영화
# Name: document, Length: 146182, dtype: object

# %%
train_data=train_data[train_data['document']!=""]
train_data.shape
# Out:
# (145791, 3)

# %%
stopwords = ['의','가','이','은','들','는','좀','드립니다',
             '잘','걍','과','도','를','으로','자',
             '에','와','한','하다','이다', '다','에게']

# %%
# 학습한 데이터에서 필요없는 단어를 필터링하는 과정
okt = Okt()


x_train = []
for d in train_data['document']: # 훈련용 데이터에서 stopword를 이용해서 필터링
  tmp_x = []
  tmp_x = okt.morphs(d, stem = True)
  tmp_x = [word for word in tmp_x if not word in stopwords] # word가 stopwords에 포함되지 않는 거만 포함
  x_train.append(tmp_x)

# %%
# 테스트 데이터 전처리
test_data.drop_duplicates(subset=['document'], inplace=True)
test_data['document']=test_data['document'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]',"")
test_data['document'].replace("", np.nan, inplace=True)
test_data = test_data.dropna(how='any')
test_data.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (48995, 3)

# %%
# 테스트 데이터 토큰화
X_test = []
for doct in test_data['document']:
    tmp_x =[]
    tmp_x =okt.morphs(doct, stem=True)  # 토큰화
    tmp_x = [word for word in tmp_x if not word in stopwords]
    X_test.append(tmp_x)

# %%
# 정수 인코딩
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)
tokenizer.word_index
# Out:
# {'영화': 1,
#  '보다': 2,
#  '을': 3,
#  '없다': 4,
#  '있다': 5,
#  '좋다': 6,
#  '너무': 7,
#  '정말': 8,
#  '되다': 9,
#  '재밌다': 10,
#  '적': 11,
#  '만': 12,
#  '같다': 13,
#  '진짜': 14,
#  '로': 15,
#  '아니다': 16,
#  '않다': 17,
#  '점': 18,
#  '에서': 19,
#  '만들다': 20,
#  '나오다': 21,
#  '연기': 22,
#  '것': 23,
#  '평점': 24,
#  '내': 25,
#  '최고': 26,
#  '그': 27,
#  '나': 28,
#  '안': 29,
#  '인': 30,
#  '스토리': 31,
#  '생각': 32,
#  '못': 33,
#  '왜': 34,
#  '드라마': 35,
#  '게': 36,
#  '감동': 37,
#  '사람': 38,
#  '보고': 39,
#  '이렇다': 40,
#  '말': 41,
#  '고': 42,
#  '아깝다': 43,
#  '더': 44,
#  '배우': 45,
#  '때': 46,
#  'ㅋㅋ': 47,
#  '아': 48,
#  '감독': 49,
#  '거': 50,
#  '그냥': 51,
#  '재미있다': 52,
#  '요': 53,
#  '재미': 54,
#  '시간': 55,
#  '내용': 56,
#  '뭐': 57,
#  '까지': 58,
#  '중': 59,
#  '주다': 60,
#  '자다': 61,
#  '하고': 62,
#  '지루하다': 63,
#  '재미없다': 64,
#  '쓰레기': 65,
#  '수': 66,
#  '네': 67,
#  '모르다': 68,
#  '가다': 69,
#  '들다': 70,
#  '그렇다': 71,
#  '싶다': 72,
#  '지': 73,
#  '작품': 74,
#  '사랑': 75,
#  '알다': 76,
#  '하나': 77,
#  '다시': 78,
#  '마지막': 79,
#  '볼': 80,
#  '이건': 81,
#  '정도': 82,
#  '저': 83,
#  '완전': 84,
#  '오다': 85,
#  'ㅋ': 86,
#  'ㅠㅠ': 87,
#  '많다': 88,
#  '처음': 89,
#  'ㅋㅋㅋ': 90,
#  '장면': 91,
#  '액션': 92,
#  '주인공': 93,
#  '이렇게': 94,
#  '안되다': 95,
#  '걸': 96,
#  '차다': 97,
#  '나다': 98,
#  '개': 99,
#  '하': 100,
#  '최악': 101,
#  '돈': 102,
#  '이야기': 103,
#  '지금': 104,
#  '넘다': 105,
#  '느낌': 106,
#  '임': 107,
#  '연출': 108,
#  'ㅡㅡ': 109,
#  '라': 110,
#  '인데': 111,
#  '듯': 112,
#  '끝': 113,
#  '명작': 114,
#  '좋아하다': 115,
#  '그리고': 116,
#  '년': 117,
#  '별로': 118,
#  '역시': 119,
#  '받다': 120,
#  '기': 121,
#  '많이': 122,
#  '남다': 123,
#  '별': 124,
#  '이해': 125,
#  '난': 126,
#  '면': 127,
#  '이런': 128,
#  '이영화': 129,
#  '분': 130,
#  '괜찮다': 131,
#  '라고': 132,
#  '느끼다': 133,
#  '또': 134,
#  '버리다': 135,
#  '이나': 136,
#  '때문': 137,
#  '성': 138,
#  '여자': 139,
#  '서': 140,
#  '부터': 141,
#  '먹다': 142,
#  '일': 143,
#  '아름답다': 144,
#  '해주다': 145,
#  '꼭': 146,
#  '보기': 147,
#  '엔': 148,
#  '이고': 149,
#  '두': 150,
#  '무슨': 151,
#  '여': 152,
#  '기억': 153,
#  '결말': 154,
#  '편': 155,
#  '대': 156,
#  'ㅎㅎ': 157,
#  '랑': 158,
#  '야': 159,
#  '짱': 160,
#  '아쉽다': 161,
#  '인생': 162,
#  '마음': 163,
#  '영': 164,
#  '소재': 165,
#  '뻔하다': 166,
#  '끄다': 167,
#  '애': 168,
#  '전': 169,
#  '보여주다': 170,
#  '님': 171,
#  '어떻다': 172,
#  '없이': 173,
#  '수준': 174,
#  '어리다': 175,
#  '현실': 176,
#  '무섭다': 177,
#  '맞다': 178,
#  '한번': 179,
#  '속': 180,
#  '씨': 181,
#  '가장': 182,
#  '재다': 183,
#  '급': 184,
#  '본': 185,
#  '웃기다': 186,
#  '반전': 187,
#  '매력': 188,
#  '되어다': 189,
#  '전개': 190,
#  '제': 191,
#  '라는': 192,
#  '한국': 193,
#  '남자': 194,
#  '끝나다': 195,
#  '가슴': 196,
#  '뿐': 197,
#  '낮다': 198,
#  '말다': 199,
#  '아이': 200,
#  '죽다': 201,
#  '슬프다': 202,
#  '높다': 203,
#  '유치하다': 204,
#  '음악': 205,
#  '알': 206,
#  '니': 207,
#  '다른': 208,
#  '멋지다': 209,
#  '원작': 210,
#  '줄': 211,
#  '늘다': 212,
#  '인간': 213,
#  '화': 214,
#  '솔직하다': 215,
#  '크다': 216,
#  '냐': 217,
#  '우리': 218,
#  '추천': 219,
#  '눈물': 220,
#  '쓰다': 221,
#  '살다': 222,
#  '인지': 223,
#  '모든': 224,
#  '지만': 225,
#  '내다': 226,
#  '함': 227,
#  '자체': 228,
#  '번': 229,
#  '야하다': 230,
#  '허다': 231,
#  '눈': 232,
#  '찍다': 233,
#  '하지만': 234,
#  '인가': 235,
#  '캐릭터': 236,
#  '보이다': 237,
#  '코미디': 238,
#  '처럼': 239,
#  'ㅋㅋㅋㅋ': 240,
#  '대한': 241,
#  '움': 242,
#  '모두': 243,
#  '이상': 244,
#  '뭔가': 245,
#  '대박': 246,
#  'ㅠ': 247,
#  '돼다': 248,
#  '이네': 249,
#  '전혀': 250,
#  '이쁘다': 251,
#  '연기력': 252,
#  '건지다': 253,
#  '여운': 254,
#  '미치다': 255,
#  '그래도': 256,
#  '짜증나다': 257,
#  '개봉': 258,
#  '공감': 259,
#  '일본': 260,
#  '기대': 261,
#  '기대하다': 262,
#  '시리즈': 263,
#  '근데': 264,
#  '중간': 265,
#  '지다': 266,
#  '표현': 267,
#  '영상': 268,
#  '부분': 269,
#  '아주': 270,
#  '모습': 271,
#  '에는': 272,
#  '작': 273,
#  '제목': 274,
#  '계속': 275,
#  '이랑': 276,
#  '치다': 277,
#  '귀엽다': 278,
#  '이라': 279,
#  '시키다': 280,
#  'ㅜㅜ': 281,
#  '가족': 282,
#  '내내': 283,
#  '뭔': 284,
#  '보지': 285,
#  '믿다': 286,
#  '진심': 287,
#  '실망': 288,
#  '몰입': 289,
#  '밖에': 290,
#  '후': 291,
#  '짜다': 292,
#  '기분': 293,
#  '대단하다': 294,
#  '연': 295,
#  '작가': 296,
#  '떨어지다': 297,
#  '건': 298,
#  '잔잔하다': 299,
#  'ㅎ': 300,
#  '이제': 301,
#  '위': 302,
#  '웃다': 303,
#  '요즘': 304,
#  '공포': 305,
#  '빠지다': 306,
#  '스릴러': 307,
#  '이라는': 308,
#  '시': 309,
#  '감': 310,
#  '긴장감': 311,
#  '개인': 312,
#  '용': 313,
#  '잼': 314,
#  '조금': 315,
#  '애니': 316,
#  '대사': 317,
#  '이유': 318,
#  '알바': 319,
#  '특히': 320,
#  '제대로': 321,
#  '삶': 322,
#  '울다': 323,
#  '극장': 324,
#  '점도': 325,
#  '노래': 326,
#  '한테': 327,
#  '딱': 328,
#  '욕': 329,
#  '굿': 330,
#  '점수': 331,
#  '잇다': 332,
#  '시작': 333,
#  '막장': 334,
#  '이란': 335,
#  '나름': 336,
#  '오랜': 337,
#  '이상하다': 338,
#  '극': 339,
#  '이지': 340,
#  '예쁘다': 341,
#  '깊다': 342,
#  '에도': 343,
#  '노잼': 344,
#  '제일': 345,
#  '차라리': 346,
#  '놈': 347,
#  '느껴지다': 348,
#  '친구': 349,
#  '해보다': 350,
#  '영화로': 351,
#  '당시': 352,
#  '같이': 353,
#  '어설프다': 354,
#  '의미': 355,
#  '절대': 356,
#  '빼다': 357,
#  '식': 358,
#  '력': 359,
#  '위해': 360,
#  '류': 361,
#  '세상': 362,
#  '따뜻하다': 363,
#  '찾다': 364,
#  '몇': 365,
#  '아직도': 366,
#  '훌륭하다': 367,
#  '이라고': 368,
#  '년대': 369,
#  '공포영화': 370,
#  '명': 371,
#  '미국': 372,
#  '웃음': 373,
#  '도대체': 374,
#  '생각나다': 375,
#  '설정': 376,
#  '아무': 377,
#  '앞': 378,
#  '무엇': 379,
#  '마다': 380,
#  '그리다': 381,
#  '오': 382,
#  '너': 383,
#  '죽이다': 384,
#  '어': 385,
#  '초반': 386,
#  '써다': 387,
#  '다르다': 388,
#  '데': 389,
#  '물': 390,
#  '뭘': 391,
#  '우리나라': 392,
#  '출연': 393,
#  '수작': 394,
#  '따다': 395,
#  '힘들다': 396,
#  '답답하다': 397,
#  '사실': 398,
#  '싫다': 399,
#  '엄청': 400,
#  '추억': 401,
#  '한국영': 402,
#  '가지': 403,
#  '반': 404,
#  '남': 405,
#  '멋있다': 406,
#  '놓다': 407,
#  '시나리오': 408,
#  '신선하다': 409,
#  '아프다': 410,
#  '관객': 411,
#  '분위기': 412,
#  '이야': 413,
#  '필요없다': 414,
#  '대다': 415,
#  '팬': 416,
#  '기다': 417,
#  '장난': 418,
#  '시대': 419,
#  '해': 420,
#  '지루함': 421,
#  '어이없다': 422,
#  '잊다': 423,
#  '세': 424,
#  '나쁘다': 425,
#  '살': 426,
#  '자신': 427,
#  '소리': 428,
#  '이딴': 429,
#  '감정': 430,
#  '졸작': 431,
#  '엔딩': 432,
#  '이지만': 433,
#  '영화관': 434,
#  '준': 435,
#  '안타깝다': 436,
#  '오늘': 437,
#  '엄마': 438,
#  '멀다': 439,
#  '구': 440,
#  '결국': 441,
#  '접': 442,
#  '제발': 443,
#  '정신': 444,
#  '봄': 445,
#  '주': 446,
#  '인상': 447,
#  '부족하다': 448,
#  '스럽다': 449,
#  '배우다': 450,
#  '더빙': 451,
#  '원': 452,
#  '더럽다': 453,
#  '포스터': 454,
#  '캐스팅': 455,
#  '라면': 456,
#  '최고다': 457,
#  '평가': 458,
#  '코믹': 459,
#  '문제': 460,
#  '니까': 461,
#  '얼마나': 462,
#  '아무리': 463,
#  '엉': 464,
#  '애니메이션': 465,
#  '함께': 466,
#  '그저': 467,
#  '어색하다': 468,
#  '몰입도': 469,
#  '서다': 470,
#  '신': 471,
#  '낫다': 472,
#  '티비': 473,
#  '기도': 474,
#  '든': 475,
#  '배경': 476,
#  '비다': 477,
#  '첨': 478,
#  '살리다': 479,
#  '두다': 480,
#  '대해': 481,
#  '유쾌하다': 482,
#  '음': 483,
#  '쓸다': 484,
#  '뒤': 485,
#  '망하다': 486,
#  '맘': 487,
#  '킬링타임': 488,
#  '나가다': 489,
#  '스릴': 490,
#  '충격': 491,
#  '완벽하다': 492,
#  '전쟁': 493,
#  '만화': 494,
#  '얘기': 495,
#  '진부하다': 496,
#  '등': 497,
#  '존나': 498,
#  '적다': 499,
#  '책': 500,
#  '건가': 501,
#  '개연': 502,
#  '예술': 503,
#  '그렇게': 504,
#  '간': 505,
#  '머': 506,
#  '머리': 507,
#  '갈수록': 508,
#  '매우': 509,
#  '질': 510,
#  '즐겁다': 511,
#  '놀라다': 512,
#  '조': 513,
#  '얼굴': 514,
#  '보단': 515,
#  '웃기': 516,
#  '후회': 517,
#  '이름': 518,
#  '읽다': 519,
#  '영화인': 520,
#  '너무나': 521,
#  '옛날': 522,
#  '구성': 523,
#  '어디': 524,
#  '어울리다': 525,
#  '행복하다': 526,
#  '집중': 527,
#  '이후': 528,
#  '들이다': 529,
#  '울': 530,
#  '총': 531,
#  '꽤': 532,
#  '장르': 533,
#  '집': 534,
#  '새롭다': 535,
#  '주연': 536,
#  '날': 537,
#  '다큐': 538,
#  '시즌': 539,
#  '상황': 540,
#  '누구': 541,
#  '그래서': 542,
#  '이리': 543,
#  '상': 544,
#  '억지': 545,
#  '언제': 546,
#  '짜증': 547,
#  '씬': 548,
#  '생기다': 549,
#  '예전': 550,
#  '글': 551,
#  '충분하다': 552,
#  '아직': 553,
#  '후반': 554,
#  '비': 555,
#  '다운': 556,
#  '역사': 557,
#  '강추': 558,
#  '어느': 559,
#  '걸작': 560,
#  '궁금하다': 561,
#  '불쌍하다': 562,
#  '여기': 563,
#  '누가': 564,
#  '밉다': 565,
#  '진': 566,
#  '약간': 567,
#  '훨씬': 568,
#  '자기': 569,
#  '소름': 570,
#  '그것': 571,
#  '인물': 572,
#  '실화': 573,
#  '발연기': 574,
#  '그나마': 575,
#  '해도': 576,
#  '그대로': 577,
#  '방송': 578,
#  '심하다': 579,
#  '분들': 580,
#  '시절': 581,
#  '만점': 582,
#  '잔인하다': 583,
#  '회': 584,
#  '비디오': 585,
#  '대체': 586,
#  '순수하다': 587,
#  '비슷하다': 588,
#  '그런': 589,
#  '드리다': 590,
#  '소설': 591,
#  '한마디': 592,
#  '사회': 593,
#  '로맨스': 594,
#  '아들': 595,
#  '어렵다': 596,
#  '부': 597,
#  '비교': 598,
#  '초딩': 599,
#  '필요하다': 600,
#  '감성': 601,
#  '판': 602,
#  '네이버': 603,
#  '쉬다': 604,
#  '따르다': 605,
#  '보': 606,
#  '휴': 607,
#  '남기다': 608,
#  '다음': 609,
#  '만나다': 610,
#  '여주': 611,
#  '여배우': 612,
#  '전체': 613,
#  '간만': 614,
#  '타다': 615,
#  '죠': 616,
#  '떠나다': 617,
#  '상당하다': 618,
#  '라도': 619,
#  '편이': 620,
#  '장': 621,
#  '나이': 622,
#  '사랑스럽다': 623,
#  '만큼': 624,
#  '이라도': 625,
#  '당하다': 626,
#  '꿈': 627,
#  '나라': 628,
#  '코': 629,
#  '성룡': 630,
#  '재': 631,
#  '굉장하다': 632,
#  '동안': 633,
#  '이르다': 634,
#  '혼자': 635,
#  '열': 636,
#  '터지다': 637,
#  '순간': 638,
#  '돌리다': 639,
#  '교훈': 640,
#  '쯤': 641,
#  '삼류': 642,
#  '보다는': 643,
#  '재밋': 644,
#  '감사하다': 645,
#  '빨리': 646,
#  '존재': 647,
#  '그만': 648,
#  '힘': 649,
#  'ㅉㅉ': 650,
#  '바로': 651,
#  '풀다': 652,
#  '주제': 653,
#  '바라다': 654,
#  '진정하다': 655,
#  '목소리': 656,
#  '에요': 657,
#  '년도': 658,
#  '억': 659,
#  '잡다': 660,
#  '죽': 661,
#  '망치다': 662,
#  '화려하다': 663,
#  '당신': 664,
#  '돋다': 665,
#  '지나다': 666,
#  '거의': 667,
#  '안보': 668,
#  '낭비': 669,
#  '몇번': 670,
#  '질질': 671,
#  '가볍다': 672,
#  '년전': 673,
#  '라니': 674,
#  '독특하다': 675,
#  '말고': 676,
#  '엄청나다': 677,
#  '줄거리': 678,
#  '맞추다': 679,
#  '성하다': 680,
#  '뜨다': 681,
#  'ㅜ': 682,
#  '의도': 683,
#  '에선': 684,
#  '딸': 685,
#  '아버지': 686,
#  '좀비': 687,
#  '판타지': 688,
#  '이번': 689,
#  '담다': 690,
#  '갑자기': 691,
#  '그러나': 692,
#  '어른': 693,
#  '넣다': 694,
#  '피': 695,
#  '전부': 696,
#  '점주': 697,
#  '당': 698,
#  '상영': 699,
#  '모': 700,
#  '시청률': 701,
#  '흥미롭다': 702,
#  '실제': 703,
#  '소': 704,
#  'ㅎㅎㅎ': 705,
#  '넘치다': 706,
#  'ㅡ': 707,
#  '힘드다': 708,
#  '평론가': 709,
#  '곳': 710,
#  '으로도': 711,
#  '맛': 712,
#  '점점': 713,
#  '필요': 714,
#  '만하': 715,
#  '땜': 716,
#  '단': 717,
#  '기다리다': 718,
#  '막': 719,
#  '한편': 720,
#  '그녀': 721,
#  '히': 722,
#  '제작': 723,
#  '화면': 724,
#  '사': 725,
#  '바': 726,
#  '대로': 727,
#  '극장판': 728,
#  '만들어지다': 729,
#  '초': 730,
#  '이기다': 731,
#  '답': 732,
#  '중국': 733,
#  '형': 734,
#  '온': 735,
#  '각본': 736,
#  '간다': 737,
#  '에서도': 738,
#  '볼때': 739,
#  '억지스럽다': 740,
#  '래': 741,
#  '밑': 742,
#  '굳다': 743,
#  '평': 744,
#  '달다': 745,
#  '바꾸다': 746,
#  '관람': 747,
#  '란': 748,
#  '오글거리다': 749,
#  '저런': 750,
#  '이하': 751,
#  '스타일': 752,
#  '세계': 753,
#  '선택': 754,
#  '선': 755,
#  '성우': 756,
#  '요소': 757,
#  '터': 758,
#  '둘': 759,
#  '복수': 760,
#  '항상': 761,
#  '일단': 762,
#  '똥': 763,
#  '가치': 764,
#  '햇': 765,
#  '어디서': 766,
#  '에서는': 767,
#  '뻔': 768,
#  '첫': 769,
#  '갖다': 770,
#  '올리다': 771,
#  '흥행': 772,
#  '부르다': 773,
#  '보내다': 774,
#  '참고': 775,
#  '그때': 776,
#  '가보다': 777,
#  '드': 778,
#  '너무하다': 779,
#  '여러': 780,
#  '걸리다': 781,
#  '더욱': 782,
#  '치고': 783,
#  '확실하다': 784,
#  '라서': 785,
#  '들어가다': 786,
#  '또한': 787,
#  '아빠': 788,
#  '평범하다': 789,
#  '씩': 790,
#  '물론': 791,
#  '수가': 792,
#  '역대': 793,
#  '발': 794,
#  '거기': 795,
#  '불편하다': 796,
#  'ㅋㅋㅋㅋㅋ': 797,
#  '인거': 798,
#  '완성': 799,
#  '편집': 800,
#  '단순하다': 801,
#  '이냐': 802,
#  '잃다': 803,
#  '상미': 804,
#  '전형': 805,
#  '멜로': 806,
#  '듣다': 807,
#  '끼다': 808,
#  '흐르다': 809,
#  '허무하다': 810,
#  '짧다': 811,
#  '새끼': 812,
#  '짓': 813,
#  '어이': 814,
#  'ㅠㅠㅠ': 815,
#  '때리다': 816,
#  '화이팅': 817,
#  '역': 818,
#  '걸다': 819,
#  '이에요': 820,
#  '귀': 821,
#  '술': 822,
#  '탄탄하다': 823,
#  '군': 824,
#  '진행': 825,
#  '가지다': 826,
#  '불륜': 827,
#  '개그': 828,
#  '에겐': 829,
#  '돋보이다': 830,
#  '엉망': 831,
#  '거지': 832,
#  '예상': 833,
#  '병맛': 834,
#  '잠': 835,
#  '사건': 836,
#  '즐기다': 837,
#  '중반': 838,
#  '지겹다': 839,
#  '미화': 840,
#  '소중하다': 841,
#  '그게': 842,
#  '똑같다': 843,
#  '어쩔': 844,
#  '설명': 845,
#  '과거': 846,
#  '메다': 847,
#  '찾아보다': 848,
#  '적당하다': 849,
#  '프랑스': 850,
#  '중요하다': 851,
#  '화보': 852,
#  '키': 853,
#  '불다': 854,
#  '훈훈하다': 855,
#  '꿀잼': 856,
#  '도저히': 857,
#  '손': 858,
#  '노력': 859,
#  '흥미진진': 860,
#  '댓글': 861,
#  '그래픽': 862,
#  '흥미': 863,
#  '닿다': 864,
#  '갈다': 865,
#  '싸우다': 866,
#  '거리': 867,
#  '여서': 868,
#  '죽음': 869,
#  '취향': 870,
#  '티': 871,
#  '무조건': 872,
#  '원래': 873,
#  '몸': 874,
#  '식상하다': 875,
#  '척': 876,
#  '리': 877,
#  '화가': 878,
#  '새': 879,
#  '뛰어나다': 880,
#  '비추다': 881,
#  '일이': 882,
#  '마르다': 883,
#  '현': 884,
#  '자극': 885,
#  '배': 886,
#  '감상': 887,
#  '며': 888,
#  '역겹다': 889,
#  '한심하다': 890,
#  '만으로도': 891,
#  '만이': 892,
#  '예': 893,
#  '학교': 894,
#  '길다': 895,
#  '자꾸': 896,
#  '괜히': 897,
#  '무': 898,
#  '액션영화': 899,
#  '암': 900,
#  '관': 901,
#  '뭐라다': 902,
#  '예고편': 903,
#  '오히려': 904,
#  '바보': 905,
#  '결혼': 906,
#  '다가': 907,
#  '심리': 908,
#  '다루다': 909,
#  '이라니': 910,
#  '게임': 911,
#  '아저씨': 912,
#  '속편': 913,
#  '용도': 914,
#  '연기자': 915,
#  '보이': 916,
#  '잘만': 917,
#  '마무리': 918,
#  '나서다': 919,
#  '올': 920,
#  '강하다': 921,
#  '관계': 922,
#  '양': 923,
#  '나르다': 924,
#  '왠만하다': 925,
#  '천재': 926,
#  '법': 927,
#  '미안하다': 928,
#  '맨': 929,
#  '흠': 930,
#  '헐다': 931,
#  'ㄷㄷ': 932,
#  '억지로': 933,
#  '표정': 934,
#  '땐': 935,
#  '참신하다': 936,
#  '영환': 937,
#  '귀신': 938,
#  '최근': 939,
#  '한다는': 940,
#  '전설': 941,
#  '순': 942,
#  '기억나다': 943,
#  '현재': 944,
#  '상상': 945,
#  '동': 946,
#  '유치': 947,
#  '젠': 948,
#  '타임': 949,
#  '촬영': 950,
#  '오빠': 951,
#  '대한민국': 952,
#  '아쉬움': 953,
#  '봣': 954,
#  '오래': 955,
#  '다니다': 956,
#  '산': 957,
#  '조차': 958,
#  '빠져들다': 959,
#  '우연히': 960,
#  '엇': 961,
#  '흘리다': 962,
#  '짐': 963,
#  '잊혀지다': 964,
#  '전편': 965,
#  '길': 966,
#  '스타': 967,
#  '묘사': 968,
#  '대작': 969,
#  '메세지': 970,
#  '진지하다': 971,
#  '만의': 972,
#  '철학': 973,
#  '겁나다': 974,
#  '타': 975,
#  '프로그램': 976,
#  '마': 977,
#  '동화': 978,
#  '프로': 979,
#  '돌아가다': 980,
#  '그림': 981,
#  '드럽다': 982,
#  '작다': 983,
#  '하하': 984,
#  '지루': 985,
#  '만에': 986,
#  '여전하다': 987,
#  '사라지다': 988,
#  '예요': 989,
#  '전달': 990,
#  '서로': 991,
#  '공': 992,
#  '역할': 993,
#  '실망하다': 994,
#  '유머': 995,
#  '등장': 996,
#  '졸라': 997,
#  '조연': 998,
#  '전작': 999,
#  '경찰': 1000,
#  ...}

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 43749
# 등장 빈도가 2번 이하인 희귀 단어의 수: 24337
# 단어 집합에서 희귀 단어의 비율: 55.62870008457336
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.9011764227704235

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어 개수는 제거.
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 19414

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV')
tokenizer.fit_on_texts(x_train)
X_train = tokenizer.texts_to_sequences(x_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
# 빈 샘플 제거
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_train[:3]
# Out:
# [404, 412, 470]

# %%
# 빈 샘플들을 제거
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 145378
# 145378
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:4454: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 71
# 리뷰의 평균 길이 : 10.83110236762096

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 15
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 15 이하인 샘플의 비율: 81.81430477788936

# %%
print('시퀀스 패딩(sample * time)')
X_train=sequence.pad_sequences(X_train,maxlen=max_len)
X_test=sequence.pad_sequences(X_test,maxlen=max_len)
print('X_train 크기 :',X_train.shape)
print('X_test 크기 : ', X_test.shape)
# Out:
# 시퀀스 패딩(sample * time)
# X_train 크기 : (145378, 15)
# X_test 크기 :  (48995, 15)

# %%
# LSTM
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
# 검증 데이터 손실(val_loss)이 증가하면,
# 과적합 징후므로 검증 데이터 손실이 4회 증가하면
# 학습을 조기 종료(Early Stopping)합니다.
es = EarlyStopping(monitor='val_loss',
                   mode='min', verbose=1, patience=4)
# ModelCheckpoint를 사용하여 검증 데이터의
# 정확도(val_acc)가 이전보다 좋아질 경우에만 모델을 저장합니다.
mc = ModelCheckpoint('best_model.h5',
                     monitor='val_acc', mode='max',
                     verbose=2, save_best_only=True)

# %%
# 리뷰 데이터를 훈련 데이터로 학습시키는 과정
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(X_train, y_train,
                    epochs=2,
                    callbacks=[es, mc],
                    batch_size=60,
                    validation_split=0.2)
# Out:
# Epoch 1/2
# 1938/1939 [============================>.] - ETA: 0s - loss: 0.3968 - acc: 0.8195
# Epoch 1: val_acc improved from -inf to 0.83719, saving model to best_model.h5
# 1939/1939 [==============================] - 128s 64ms/step - loss: 0.3968 - acc: 0.8196 - val_loss: 0.3683 - val_acc: 0.8372
# Epoch 2/2
# 1938/1939 [============================>.] - ETA: 0s - loss: 0.3392 - acc: 0.8510
# Epoch 2: val_acc improved from 0.83719 to 0.84860, saving model to best_model.h5
# 1939/1939 [==============================] - 109s 56ms/step - loss: 0.3392 - acc: 0.8510 - val_loss: 0.3458 - val_acc: 0.8486

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1532/1532 [==============================] - 12s 8ms/step - loss: 0.3521 - acc: 0.8424
#
#  테스트 정확도: 0.8424

# %%
def sentiment_predict(new_sentence):
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = sequence.pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# 79.38% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이게 영화냐?ㅠㅠ')
# Out:
# 89.79% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('이 영화 개재미 없음')
# Out:
# 98.04% 확률로 부정 리뷰입니다.
