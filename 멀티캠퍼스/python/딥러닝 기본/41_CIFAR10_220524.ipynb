# %% [markdown]
# # CIFAR-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
#  - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X_data: scaling
X_train = X_train / 255.
X_test = X_test / 255.

# %%
# y_data: one hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
#  - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
                    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
                    Conv2D(32, (3,3), activation='relu'),
                    MaxPooling2D(),
                    Dropout(0.25),
                    Conv2D(64, (3,3), padding='same', activation='relu'),
                    Conv2D(64, (3,3), activation='relu'),
                    MaxPooling2D(),
                    Dropout(0.25),
                    Flatten(),
                    Dense(512, activation='relu'),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_path = 'best-cifar10_v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2, epochs=100, batch_size=32, callbacks=[mc,es])
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.8293 - accuracy: 0.3273
# Epoch 1: val_loss improved from inf to 1.57574, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 20s 6ms/step - loss: 1.8293 - accuracy: 0.3273 - val_loss: 1.5757 - val_accuracy: 0.4274
# Epoch 2/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.5240 - accuracy: 0.4417
# Epoch 2: val_loss improved from 1.57574 to 1.38254, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.5234 - accuracy: 0.4421 - val_loss: 1.3825 - val_accuracy: 0.5044
# Epoch 3/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.3971 - accuracy: 0.4940
# Epoch 3: val_loss improved from 1.38254 to 1.27389, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3969 - accuracy: 0.4942 - val_loss: 1.2739 - val_accuracy: 0.5516
# Epoch 4/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.3003 - accuracy: 0.5338
# Epoch 4: val_loss improved from 1.27389 to 1.23662, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3005 - accuracy: 0.5337 - val_loss: 1.2366 - val_accuracy: 0.5576
# Epoch 5/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.2226 - accuracy: 0.5653
# Epoch 5: val_loss improved from 1.23662 to 1.19396, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.2224 - accuracy: 0.5653 - val_loss: 1.1940 - val_accuracy: 0.5838
# Epoch 6/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1597 - accuracy: 0.5892
# Epoch 6: val_loss improved from 1.19396 to 1.06364, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.1597 - accuracy: 0.5891 - val_loss: 1.0636 - val_accuracy: 0.6297
# Epoch 7/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1049 - accuracy: 0.6145
# Epoch 7: val_loss did not improve from 1.06364
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.1049 - accuracy: 0.6145 - val_loss: 1.0741 - val_accuracy: 0.6192
# Epoch 8/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0613 - accuracy: 0.6287
# Epoch 8: val_loss improved from 1.06364 to 0.98688, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0604 - accuracy: 0.6291 - val_loss: 0.9869 - val_accuracy: 0.6511
# Epoch 9/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.0177 - accuracy: 0.6430
# Epoch 9: val_loss improved from 0.98688 to 0.97045, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0177 - accuracy: 0.6433 - val_loss: 0.9704 - val_accuracy: 0.6606
# Epoch 10/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9834 - accuracy: 0.6547
# Epoch 10: val_loss did not improve from 0.97045
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9833 - accuracy: 0.6547 - val_loss: 0.9829 - val_accuracy: 0.6543
# Epoch 11/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9536 - accuracy: 0.6687
# Epoch 11: val_loss improved from 0.97045 to 0.88745, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9539 - accuracy: 0.6687 - val_loss: 0.8874 - val_accuracy: 0.6874
# Epoch 12/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.9254 - accuracy: 0.6753
# Epoch 12: val_loss improved from 0.88745 to 0.88043, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9257 - accuracy: 0.6752 - val_loss: 0.8804 - val_accuracy: 0.6899
# Epoch 13/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.9022 - accuracy: 0.6843
# Epoch 13: val_loss did not improve from 0.88043
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9023 - accuracy: 0.6843 - val_loss: 0.8826 - val_accuracy: 0.6885
# Epoch 14/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8806 - accuracy: 0.6937
# Epoch 14: val_loss improved from 0.88043 to 0.83234, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8805 - accuracy: 0.6938 - val_loss: 0.8323 - val_accuracy: 0.7060
# Epoch 15/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.8563 - accuracy: 0.7032
# Epoch 15: val_loss did not improve from 0.83234
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8561 - accuracy: 0.7035 - val_loss: 0.8379 - val_accuracy: 0.7074
# Epoch 16/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8411 - accuracy: 0.7058
# Epoch 16: val_loss improved from 0.83234 to 0.81711, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8411 - accuracy: 0.7058 - val_loss: 0.8171 - val_accuracy: 0.7180
# Epoch 17/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8258 - accuracy: 0.7126
# Epoch 17: val_loss improved from 0.81711 to 0.78311, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8253 - accuracy: 0.7130 - val_loss: 0.7831 - val_accuracy: 0.7267
# Epoch 18/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8063 - accuracy: 0.7202
# Epoch 18: val_loss improved from 0.78311 to 0.77711, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8063 - accuracy: 0.7203 - val_loss: 0.7771 - val_accuracy: 0.7306
# Epoch 19/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7953 - accuracy: 0.7231
# Epoch 19: val_loss improved from 0.77711 to 0.77555, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7951 - accuracy: 0.7233 - val_loss: 0.7756 - val_accuracy: 0.7296
# Epoch 20/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7824 - accuracy: 0.7325
# Epoch 20: val_loss improved from 0.77555 to 0.76962, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7823 - accuracy: 0.7325 - val_loss: 0.7696 - val_accuracy: 0.7353
# Epoch 21/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7706 - accuracy: 0.7317
# Epoch 21: val_loss did not improve from 0.76962
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7703 - accuracy: 0.7319 - val_loss: 0.7740 - val_accuracy: 0.7316
# Epoch 22/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.7359
# Epoch 22: val_loss improved from 0.76962 to 0.75290, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7618 - accuracy: 0.7359 - val_loss: 0.7529 - val_accuracy: 0.7425
# Epoch 23/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7515 - accuracy: 0.7437
# Epoch 23: val_loss improved from 0.75290 to 0.74038, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7521 - accuracy: 0.7434 - val_loss: 0.7404 - val_accuracy: 0.7489
# Epoch 24/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7371 - accuracy: 0.7458
# Epoch 24: val_loss improved from 0.74038 to 0.72316, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7370 - accuracy: 0.7458 - val_loss: 0.7232 - val_accuracy: 0.7534
# Epoch 25/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7338 - accuracy: 0.7484
# Epoch 25: val_loss improved from 0.72316 to 0.72167, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7337 - accuracy: 0.7485 - val_loss: 0.7217 - val_accuracy: 0.7530
# Epoch 26/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7238 - accuracy: 0.7539
# Epoch 26: val_loss improved from 0.72167 to 0.71415, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7238 - accuracy: 0.7539 - val_loss: 0.7142 - val_accuracy: 0.7599
# Epoch 27/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7198 - accuracy: 0.7539
# Epoch 27: val_loss improved from 0.71415 to 0.70731, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7198 - accuracy: 0.7539 - val_loss: 0.7073 - val_accuracy: 0.7586
# Epoch 28/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7121 - accuracy: 0.7559
# Epoch 28: val_loss did not improve from 0.70731
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7128 - accuracy: 0.7557 - val_loss: 0.7143 - val_accuracy: 0.7522
# Epoch 29/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7063 - accuracy: 0.7584
# Epoch 29: val_loss improved from 0.70731 to 0.69906, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7063 - accuracy: 0.7585 - val_loss: 0.6991 - val_accuracy: 0.7596
# Epoch 30/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7026 - accuracy: 0.7617
# Epoch 30: val_loss did not improve from 0.69906
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7026 - accuracy: 0.7616 - val_loss: 0.7018 - val_accuracy: 0.7624
# Epoch 31/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6991 - accuracy: 0.7630
# Epoch 31: val_loss did not improve from 0.69906
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6996 - accuracy: 0.7629 - val_loss: 0.7004 - val_accuracy: 0.7618
# Epoch 32/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6945 - accuracy: 0.7637
# Epoch 32: val_loss did not improve from 0.69906
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6948 - accuracy: 0.7636 - val_loss: 0.7154 - val_accuracy: 0.7555
# Epoch 33/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6851 - accuracy: 0.7655
# Epoch 33: val_loss improved from 0.69906 to 0.69453, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6851 - accuracy: 0.7655 - val_loss: 0.6945 - val_accuracy: 0.7617
# Epoch 34/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6811 - accuracy: 0.7685
# Epoch 34: val_loss did not improve from 0.69453
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6807 - accuracy: 0.7689 - val_loss: 0.7024 - val_accuracy: 0.7631
# Epoch 35/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6806 - accuracy: 0.7692
# Epoch 35: val_loss did not improve from 0.69453
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6798 - accuracy: 0.7695 - val_loss: 0.7117 - val_accuracy: 0.7593
# Epoch 36/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.7697
# Epoch 36: val_loss improved from 0.69453 to 0.69010, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6825 - accuracy: 0.7697 - val_loss: 0.6901 - val_accuracy: 0.7655
# Epoch 37/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6777 - accuracy: 0.7678
# Epoch 37: val_loss improved from 0.69010 to 0.67068, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6771 - accuracy: 0.7679 - val_loss: 0.6707 - val_accuracy: 0.7694
# Epoch 38/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.7710
# Epoch 38: val_loss did not improve from 0.67068
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6727 - accuracy: 0.7712 - val_loss: 0.7047 - val_accuracy: 0.7642
# Epoch 39/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6662 - accuracy: 0.7742
# Epoch 39: val_loss did not improve from 0.67068
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6664 - accuracy: 0.7742 - val_loss: 0.6804 - val_accuracy: 0.7681
# Epoch 40/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6669 - accuracy: 0.7727
# Epoch 40: val_loss did not improve from 0.67068
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6666 - accuracy: 0.7728 - val_loss: 0.6851 - val_accuracy: 0.7648
# Epoch 41/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6638 - accuracy: 0.7769
# Epoch 41: val_loss did not improve from 0.67068
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6638 - accuracy: 0.7770 - val_loss: 0.6870 - val_accuracy: 0.7678
# Epoch 42/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6628 - accuracy: 0.7780
# Epoch 42: val_loss did not improve from 0.67068
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6637 - accuracy: 0.7778 - val_loss: 0.6885 - val_accuracy: 0.7676
# Epoch 43/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6525 - accuracy: 0.7828
# Epoch 43: val_loss improved from 0.67068 to 0.66764, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6530 - accuracy: 0.7826 - val_loss: 0.6676 - val_accuracy: 0.7741
# Epoch 44/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6572 - accuracy: 0.7792
# Epoch 44: val_loss did not improve from 0.66764
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6572 - accuracy: 0.7792 - val_loss: 0.6781 - val_accuracy: 0.7713
# Epoch 45/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.7810
# Epoch 45: val_loss did not improve from 0.66764
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6543 - accuracy: 0.7810 - val_loss: 0.6829 - val_accuracy: 0.7770
# Epoch 46/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.7812
# Epoch 46: val_loss did not improve from 0.66764
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6468 - accuracy: 0.7812 - val_loss: 0.6705 - val_accuracy: 0.7711
# Epoch 47/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6476 - accuracy: 0.7836
# Epoch 47: val_loss improved from 0.66764 to 0.66250, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6479 - accuracy: 0.7835 - val_loss: 0.6625 - val_accuracy: 0.7749
# Epoch 48/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6411 - accuracy: 0.7836
# Epoch 48: val_loss improved from 0.66250 to 0.66047, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6411 - accuracy: 0.7836 - val_loss: 0.6605 - val_accuracy: 0.7792
# Epoch 49/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6401 - accuracy: 0.7855
# Epoch 49: val_loss did not improve from 0.66047
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6402 - accuracy: 0.7857 - val_loss: 0.6677 - val_accuracy: 0.7775
# Epoch 50/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.7871
# Epoch 50: val_loss did not improve from 0.66047
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6347 - accuracy: 0.7872 - val_loss: 0.6791 - val_accuracy: 0.7722
# Epoch 51/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6305 - accuracy: 0.7887
# Epoch 51: val_loss improved from 0.66047 to 0.64548, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6306 - accuracy: 0.7888 - val_loss: 0.6455 - val_accuracy: 0.7792
# Epoch 52/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6342 - accuracy: 0.7879
# Epoch 52: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6351 - accuracy: 0.7876 - val_loss: 0.6536 - val_accuracy: 0.7790
# Epoch 53/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6277 - accuracy: 0.7858
# Epoch 53: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6275 - accuracy: 0.7860 - val_loss: 0.6827 - val_accuracy: 0.7734
# Epoch 54/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6335 - accuracy: 0.7883
# Epoch 54: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6333 - accuracy: 0.7884 - val_loss: 0.6502 - val_accuracy: 0.7823
# Epoch 55/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6256 - accuracy: 0.7937
# Epoch 55: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6256 - accuracy: 0.7936 - val_loss: 0.6671 - val_accuracy: 0.7827
# Epoch 56/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6257 - accuracy: 0.7892
# Epoch 56: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6262 - accuracy: 0.7891 - val_loss: 0.6663 - val_accuracy: 0.7777
# Epoch 57/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.7903
# Epoch 57: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6251 - accuracy: 0.7905 - val_loss: 0.6517 - val_accuracy: 0.7829
# Epoch 58/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6230 - accuracy: 0.7914
# Epoch 58: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6226 - accuracy: 0.7916 - val_loss: 0.7317 - val_accuracy: 0.7632
# Epoch 59/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6168 - accuracy: 0.7918
# Epoch 59: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6168 - accuracy: 0.7918 - val_loss: 0.6955 - val_accuracy: 0.7725
# Epoch 60/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6157 - accuracy: 0.7942
# Epoch 60: val_loss did not improve from 0.64548
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6157 - accuracy: 0.7942 - val_loss: 0.6719 - val_accuracy: 0.7793
# Epoch 61/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6151 - accuracy: 0.7971
# Epoch 61: val_loss improved from 0.64548 to 0.64444, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6151 - accuracy: 0.7971 - val_loss: 0.6444 - val_accuracy: 0.7840
# Epoch 62/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6055 - accuracy: 0.7956
# Epoch 62: val_loss did not improve from 0.64444
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6060 - accuracy: 0.7955 - val_loss: 0.6833 - val_accuracy: 0.7692
# Epoch 63/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6165 - accuracy: 0.7943
# Epoch 63: val_loss did not improve from 0.64444
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6168 - accuracy: 0.7940 - val_loss: 0.6822 - val_accuracy: 0.7752
# Epoch 64/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6113 - accuracy: 0.7936
# Epoch 64: val_loss improved from 0.64444 to 0.64000, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6107 - accuracy: 0.7938 - val_loss: 0.6400 - val_accuracy: 0.7861
# Epoch 65/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6101 - accuracy: 0.7958
# Epoch 65: val_loss did not improve from 0.64000
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6099 - accuracy: 0.7956 - val_loss: 0.6491 - val_accuracy: 0.7848
# Epoch 66/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6066 - accuracy: 0.7989
# Epoch 66: val_loss improved from 0.64000 to 0.63677, saving model to best-cifar10_v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6069 - accuracy: 0.7987 - val_loss: 0.6368 - val_accuracy: 0.7862
# Epoch 67/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6038 - accuracy: 0.7981
# Epoch 67: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6033 - accuracy: 0.7981 - val_loss: 0.6646 - val_accuracy: 0.7813
# Epoch 68/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.7959
# Epoch 68: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6070 - accuracy: 0.7959 - val_loss: 0.6456 - val_accuracy: 0.7856
# Epoch 69/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6022 - accuracy: 0.7996
# Epoch 69: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6014 - accuracy: 0.7999 - val_loss: 0.6534 - val_accuracy: 0.7822
# Epoch 70/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6034 - accuracy: 0.7989
# Epoch 70: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6034 - accuracy: 0.7988 - val_loss: 0.6524 - val_accuracy: 0.7821
# Epoch 71/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.5990 - accuracy: 0.8011
# Epoch 71: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5994 - accuracy: 0.8010 - val_loss: 0.6500 - val_accuracy: 0.7872
# Epoch 72/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6039 - accuracy: 0.7961
# Epoch 72: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6041 - accuracy: 0.7961 - val_loss: 0.6509 - val_accuracy: 0.7842
# Epoch 73/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.5936 - accuracy: 0.8017
# Epoch 73: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5940 - accuracy: 0.8014 - val_loss: 0.6462 - val_accuracy: 0.7877
# Epoch 74/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.5946 - accuracy: 0.8010
# Epoch 74: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5953 - accuracy: 0.8006 - val_loss: 0.6657 - val_accuracy: 0.7813
# Epoch 75/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.5952 - accuracy: 0.8024
# Epoch 75: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5951 - accuracy: 0.8024 - val_loss: 0.6471 - val_accuracy: 0.7836
# Epoch 76/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5983 - accuracy: 0.8024
# Epoch 76: val_loss did not improve from 0.63677
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5981 - accuracy: 0.8025 - val_loss: 0.6540 - val_accuracy: 0.7822

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6552 - accuracy: 0.7815
# [0.6552222967147827, 0.781499981880188]

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim(0,1.2),
plt.xlabel('Epoch')
plt.title('Cifar-10 CNN model v1')
plt.show()
