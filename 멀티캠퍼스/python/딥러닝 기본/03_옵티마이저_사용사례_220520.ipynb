# %% [markdown]
# # 신경망 모델에서 옵티마이저 사용법
#  - 이진분류: 유방암 예측 사례

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
cancer = load_breast_cancer()
cancer_std = StandardScaler().fit_transform(cancer.data)
X_train, X_test, y_train, y_test = train_test_split(cancer_std, cancer.target, stratify = cancer.target, test_size=0.2, random_state=2022)

# %% [markdown]
# - Adam Optimizer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Dense(100, input_dim=30, activation='relu'),
                    Dense(24, activation='relu'), Dense(1, activation='sigmoid')])

# %% [markdown]
# #### Adam 하이퍼 파라메터
# - learning_rate: 0보다 크거나 같은 float 값. 학습률.
# - beta_1: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - beta_2: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - epsilon: 0보다 크거나 같은 float형 fuzz factor. None인 경우 K.epsilon()이 사용됩니다.
# - decay: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.
# - amsgrad: 불리언. Adam의 변형인 AMSGrad의 적용 여부를 설정합니다

# %%
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate = 0.001, beta_1 = 0.9, beta_2 = 0.999, epsilon=None, decay=0.0, amsgrad=False)

# %%
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=100, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0573 - accuracy: 0.9825
# [0.05734206736087799, 0.9824561476707458]

# %%
y_acc = hist.history['accuracy']
y_vloss=hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('Adam optimizer')
plt.show()

# %% [markdown]
# ### 2. RMSProp Optimizer

# %%
model2 = Sequential([Dense(100, input_dim=30, activation='relu'),
                    Dense(24, activation='relu'), Dense(1, activation='sigmoid')])

# %% [markdown]
# #### RMSprop 하이퍼 파라메터
# - lr: 0보다 크거나 같은 float 값. 학습률.
# - rho: 0보다 크거나 같은 float 값.
# - epsilon: 0보다 크거나 같은 float형 fuzz factor. None인 경우 K.epsilon()이 사용됩니다.
# - decay: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.

# %%
from tensorflow.keras.optimizers import RMSprop
rmsp = RMSprop(learning_rate = 0.001, rho=0.9, epsilon=None, decay=0.0)

# %%
model2.compile(rmsp,'binary_crossentropy',['accuracy'])

# %%
hist2 = model2.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=100, verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 2s - loss: 0.6094 - accuracy: 0.6374 - val_loss: 0.4671 - val_accuracy: 0.8791 - 2s/epoch - 388ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.4046 - accuracy: 0.9203 - val_loss: 0.3672 - val_accuracy: 0.8901 - 59ms/epoch - 15ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.3159 - accuracy: 0.9505 - val_loss: 0.3037 - val_accuracy: 0.9011 - 65ms/epoch - 16ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.2575 - accuracy: 0.9588 - val_loss: 0.2612 - val_accuracy: 0.9011 - 57ms/epoch - 14ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.2156 - accuracy: 0.9615 - val_loss: 0.2285 - val_accuracy: 0.9231 - 62ms/epoch - 16ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.1844 - accuracy: 0.9615 - val_loss: 0.2026 - val_accuracy: 0.9341 - 52ms/epoch - 13ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.1598 - accuracy: 0.9670 - val_loss: 0.1838 - val_accuracy: 0.9341 - 55ms/epoch - 14ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.1402 - accuracy: 0.9780 - val_loss: 0.1693 - val_accuracy: 0.9341 - 58ms/epoch - 14ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.1241 - accuracy: 0.9780 - val_loss: 0.1589 - val_accuracy: 0.9341 - 65ms/epoch - 16ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.1110 - accuracy: 0.9835 - val_loss: 0.1503 - val_accuracy: 0.9451 - 55ms/epoch - 14ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.0998 - accuracy: 0.9808 - val_loss: 0.1411 - val_accuracy: 0.9451 - 63ms/epoch - 16ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.0903 - accuracy: 0.9808 - val_loss: 0.1356 - val_accuracy: 0.9451 - 52ms/epoch - 13ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.0830 - accuracy: 0.9835 - val_loss: 0.1310 - val_accuracy: 0.9451 - 65ms/epoch - 16ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.0761 - accuracy: 0.9863 - val_loss: 0.1302 - val_accuracy: 0.9451 - 82ms/epoch - 20ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.0709 - accuracy: 0.9808 - val_loss: 0.1278 - val_accuracy: 0.9451 - 58ms/epoch - 14ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.0660 - accuracy: 0.9835 - val_loss: 0.1274 - val_accuracy: 0.9451 - 58ms/epoch - 14ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.0617 - accuracy: 0.9835 - val_loss: 0.1249 - val_accuracy: 0.9341 - 55ms/epoch - 14ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.0579 - accuracy: 0.9863 - val_loss: 0.1263 - val_accuracy: 0.9451 - 52ms/epoch - 13ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.0543 - accuracy: 0.9863 - val_loss: 0.1229 - val_accuracy: 0.9341 - 49ms/epoch - 12ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.0518 - accuracy: 0.9863 - val_loss: 0.1210 - val_accuracy: 0.9560 - 51ms/epoch - 13ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.0491 - accuracy: 0.9863 - val_loss: 0.1234 - val_accuracy: 0.9560 - 72ms/epoch - 18ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.0460 - accuracy: 0.9863 - val_loss: 0.1218 - val_accuracy: 0.9560 - 59ms/epoch - 15ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.0444 - accuracy: 0.9863 - val_loss: 0.1240 - val_accuracy: 0.9341 - 54ms/epoch - 13ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.0419 - accuracy: 0.9863 - val_loss: 0.1174 - val_accuracy: 0.9341 - 57ms/epoch - 14ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.0396 - accuracy: 0.9890 - val_loss: 0.1181 - val_accuracy: 0.9341 - 53ms/epoch - 13ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.0373 - accuracy: 0.9890 - val_loss: 0.1168 - val_accuracy: 0.9341 - 60ms/epoch - 15ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.0354 - accuracy: 0.9918 - val_loss: 0.1200 - val_accuracy: 0.9341 - 59ms/epoch - 15ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.0332 - accuracy: 0.9945 - val_loss: 0.1205 - val_accuracy: 0.9451 - 59ms/epoch - 15ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.0317 - accuracy: 0.9945 - val_loss: 0.1143 - val_accuracy: 0.9451 - 58ms/epoch - 14ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.0303 - accuracy: 0.9918 - val_loss: 0.1169 - val_accuracy: 0.9451 - 60ms/epoch - 15ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.0285 - accuracy: 0.9918 - val_loss: 0.1179 - val_accuracy: 0.9451 - 56ms/epoch - 14ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.0269 - accuracy: 0.9945 - val_loss: 0.1174 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.0256 - accuracy: 0.9945 - val_loss: 0.1197 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.0242 - accuracy: 0.9945 - val_loss: 0.1155 - val_accuracy: 0.9451 - 58ms/epoch - 14ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.0223 - accuracy: 0.9945 - val_loss: 0.1189 - val_accuracy: 0.9451 - 61ms/epoch - 15ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.0213 - accuracy: 0.9945 - val_loss: 0.1147 - val_accuracy: 0.9451 - 64ms/epoch - 16ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.1222 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.1159 - val_accuracy: 0.9451 - 55ms/epoch - 14ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.0177 - accuracy: 0.9945 - val_loss: 0.1189 - val_accuracy: 0.9451 - 53ms/epoch - 13ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.1211 - val_accuracy: 0.9451 - 49ms/epoch - 12ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.1251 - val_accuracy: 0.9451 - 50ms/epoch - 13ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.0147 - accuracy: 0.9973 - val_loss: 0.1302 - val_accuracy: 0.9341 - 51ms/epoch - 13ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9451 - 56ms/epoch - 14ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9451 - 56ms/epoch - 14ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.1251 - val_accuracy: 0.9451 - 53ms/epoch - 13ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.1281 - val_accuracy: 0.9341 - 85ms/epoch - 21ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9451 - 69ms/epoch - 17ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9451 - 64ms/epoch - 16ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9451 - 66ms/epoch - 17ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9451 - 64ms/epoch - 16ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9451 - 59ms/epoch - 15ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9451 - 59ms/epoch - 15ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9451 - 53ms/epoch - 13ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9451 - 54ms/epoch - 13ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9451 - 54ms/epoch - 14ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9451 - 52ms/epoch - 13ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9451 - 61ms/epoch - 15ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9560 - 56ms/epoch - 14ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9451 - 71ms/epoch - 18ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9451 - 66ms/epoch - 16ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9451 - 49ms/epoch - 12ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9451 - 53ms/epoch - 13ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9451 - 55ms/epoch - 14ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9451 - 67ms/epoch - 17ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9560 - 53ms/epoch - 13ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9560 - 64ms/epoch - 16ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9451 - 51ms/epoch - 13ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9560 - 52ms/epoch - 13ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9451 - 55ms/epoch - 14ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 9.4393e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9451 - 57ms/epoch - 14ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 9.2222e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9451 - 58ms/epoch - 15ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 8.5851e-04 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9560 - 63ms/epoch - 16ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 7.7849e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9560 - 68ms/epoch - 17ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 6.9911e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 6.7655e-04 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9560 - 61ms/epoch - 15ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 5.5757e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9560 - 51ms/epoch - 13ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 5.4620e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 4.4650e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9560 - 58ms/epoch - 15ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 4.0210e-04 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9451 - 58ms/epoch - 14ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 4.2924e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9560 - 60ms/epoch - 15ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 3.8452e-04 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9560 - 53ms/epoch - 13ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 3.1720e-04 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9560 - 63ms/epoch - 16ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 3.1911e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9560 - 58ms/epoch - 14ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 2.4723e-04 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9451 - 49ms/epoch - 12ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 2.5794e-04 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 2.0058e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9560 - 53ms/epoch - 13ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 1.9009e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9560 - 53ms/epoch - 13ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 1.7595e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9560 - 58ms/epoch - 15ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 1.5796e-04 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9560 - 73ms/epoch - 18ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 1.4569e-04 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9560 - 63ms/epoch - 16ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 1.3098e-04 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9560 - 57ms/epoch - 14ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 1.0474e-04 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 9.5571e-05 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9451 - 52ms/epoch - 13ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 9.2498e-05 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9560 - 63ms/epoch - 16ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 7.5401e-05 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9560 - 59ms/epoch - 15ms/step

# %%
model2.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.9825
# [0.12769390642642975, 0.9824561476707458]

# %%
y_acc2 = hist2.history['accuracy']
y_vloss2=hist2.history['val_loss']
xs = np.arange(1,len(y_acc2)+1)

# %%
plt.figure(figsize=(20,8))
plt.subplot(121)
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('Adam optimizer')

plt.subplot(122)
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('RMSprop optimizer')
plt.show()
